# %% [markdown]
# # Image-Based Model Drift Detection with EMNIST

# %% [markdown]
# ## Description of Method
#
# This notebook will run through an example of the model drift detection pipeline described in [here](https://) (for a high level understanding of each of the steps in this example, check out the [slides](https://) provided in the git repo).
#
# To concretely detect model drift on the open-source EMNIST dataset, we will create a base model and a production model from two different portions of the dataset. Then, using both model inversion and membership inference attacks, we will determine whether the base model's general idea of a feature or class has drifted, even if the test accuracy scores do not indicate that.

# %% [markdown]
# # Detecting Model Drift Example

# %% [markdown]
# Let's Begin!

# %%
# !pip install adversarial-robustness-toolbox # version 1.15.1
# !pip install pyyaml h5py  # Required to save models in HDF5 format

import os
import sys
import sklearn
import numpy as np
import tensorflow as tf
import tensorflow_datasets as tfds

# dataset management
from tensorflow.keras.datasets import cifar10, mnist, fashion_mnist
tfds.image_classification.EMNIST
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

# to initialize model
from tensorflow.keras.layers import Input, Dense, Flatten, Conv2D, MaxPooling2D, Activation, Dropout, \
    BatchNormalization, AveragePooling2D, Add, Conv1D, MaxPooling1D, Embedding
from tensorflow.keras.regularizers import l2
from tensorflow.keras.optimizers import Adam

# for model training
from tensorflow.keras.losses import categorical_crossentropy

# for model evaluation
from sklearn.metrics import classification_report
# Out:
# Collecting adversarial-robustness-toolbox
#   Downloading adversarial_robustness_toolbox-1.15.1-py3-none-any.whl (1.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 14.5 MB/s eta 0:00:00
# Requirement already satisfied: numpy>=1.18.0 in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (1.23.5)
# Requirement already satisfied: scipy>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (1.10.1)
# Collecting scikit-learn<1.2.0,>=0.22.2 (from adversarial-robustness-toolbox)
#   Downloading scikit_learn-1.1.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 30.5/30.5 MB 50.1 MB/s eta 0:00:00
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (1.16.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (67.7.2)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from adversarial-robustness-toolbox) (4.66.1)
# Requirement already satisfied: joblib>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2.0,>=0.22.2->adversarial-robustness-toolbox) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from scikit-learn<1.2.0,>=0.22.2->adversarial-robustness-toolbox) (3.2.0)
# Installing collected packages: scikit-learn, adversarial-robustness-toolbox
#   Attempting uninstall: scikit-learn
#     Found existing installation: scikit-learn 1.2.2
#     Uninstalling scikit-learn-1.2.2:
#       Successfully uninstalled scikit-learn-1.2.2
# Successfully installed adversarial-robustness-toolbox-1.15.1 scikit-learn-1.1.3
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.10/dist-packages (6.0.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.10/dist-packages (3.9.0)
# Requirement already satisfied: numpy>=1.17.3 in /usr/local/lib/python3.10/dist-packages (from h5py) (1.23.5)

# %% [markdown]
# ### Data Management

# %% [markdown]
# As a first data management step, we must establish the proper configuration for the dataset and the model.
#
# *For a description of these variables, see [Configuration Notes](#Configuration-Notes).*

# %%
# DATASET CONFIGURATION
num_classes = 47
image_size = 28
image_channels = 1
conv_filters = [
    32,
    64
]
dense_units = 1028
mode = "natural"
depth = 1
# TRAINING CONFIGURATION
EPOCHS = 20
batch_size = 128
train_size = 0.2
test_size = 0.2
examples_per_class = 100

# %% [markdown]
# Now, we load in the dataset and assign the training and testing data.

# %%
label_key = 'label'

# get EMNIST train data
ds, ds_info = tfds.load('emnist', with_info=True, split='train', data_dir='data')
num_classes = ds_info.features[label_key].num_classes

ds_numpy = tfds.as_numpy(ds)
x_trn, y_trn = [], []
for ex in ds_numpy:
    x_trn.append(ex['image'])
    y_trn.append(ex[label_key])

x_train = np.array(x_trn)
y_train = np.array(y_trn)

# get EMNIST test data
ds, ds_info = tfds.load('emnist', with_info=True, split='test', data_dir='data')
num_classes = ds_info.features[label_key].num_classes

ds_numpy = tfds.as_numpy(ds)
x_tst, y_tst= [], []
for ex in ds_numpy:
    x_tst.append(ex['image'])
    y_tst.append(ex[label_key])

x_test = np.array(x_tst)
y_test = np.array(y_tst)

# normalize images
x_train = x_train.astype('float32') / 255
x_test = x_test.astype('float32') / 255

y_train = to_categorical(y_train, num_classes)
y_test = to_categorical(y_test, num_classes)
# Out:
# Downloading and preparing dataset 535.73 MiB (download: 535.73 MiB, generated: Unknown size, total: 535.73 MiB) to data/emnist/byclass/3.0.0...
# Dl Completed...: 0 url [00:00, ? url/s]
# Dl Size...: 0 MiB [00:00, ? MiB/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Extraction completed...: 0 file [00:00, ? file/s]
# Generating splits...:   0%|          | 0/2 [00:00<?, ? splits/s]
# Generating train examples...:   0%|          | 0/697932 [00:00<?, ? examples/s]
# Shuffling data/emnist/byclass/3.0.0.incompleteEOGMDI/emnist-train.tfrecord*...:   0%|          | 0/697932 [00:…
# Generating test examples...:   0%|          | 0/116323 [00:00<?, ? examples/s]
# Shuffling data/emnist/byclass/3.0.0.incompleteEOGMDI/emnist-test.tfrecord*...:   0%|          | 0/116323 [00:0…
# Dataset emnist downloaded and prepared to data/emnist/byclass/3.0.0. Subsequent calls will reuse this data.

# %% [markdown]
# Here, we split the data into the base training data (**x_base, y_base**) and the production training data (**x_production, y_production**).

# %%
# reshape y_train
def flatten_y(y_temp):
    y_flatten = []
    for y_idx in range(len(y_temp)):
        y_flatten.append(np.argmax(y_temp[y_idx]))
    y_flatten = np.array(y_flatten)
    return y_flatten

x_base = x_train
y_base = y_train

y_flatten = flatten_y(y_base)
ids = np.array(list(range(len(y_flatten))))

ids_base, ids_prod = train_test_split(ids, train_size=train_size, test_size=test_size, random_state=None, shuffle = True, stratify=y_flatten)

x_base = x_train[ids_base]
y_base = y_train[ids_base]
x_production = x_train[ids_prod]
y_production = y_train[ids_prod]

# %% [markdown]
# Let's make sure that our training and testing shapes for the base and production data are what we expect...

# %%
print("original training data x and y shapes:")
print(x_train.shape)
print(y_train.shape)

print("base training data x and y shapes:")
print(x_base.shape)
print(y_base.shape)

print("drifted production training data x and y shapes:")
print(x_production.shape)
print(y_production.shape)

print("testing data x and y shapes:")
print(x_test.shape)
print(y_test.shape)
# Out:
# original training data x and y shapes:
# (697932, 28, 28, 1)
# (697932, 62)
# base training data x and y shapes:
# (139586, 28, 28, 1)
# (139586, 62)
# drifted production training data x and y shapes:
# (139587, 28, 28, 1)
# (139587, 62)
# testing data x and y shapes:
# (116323, 28, 28, 1)
# (116323, 62)

# %% [markdown]
# ## Model Creation
#
# Now, we have access to our train and test data in the correctly loaded configuration. The next step is to create the base model using **x_base** and **y_base**.

# %% [markdown]
# Here, we set the hyperparameters based on the model type and configuration settings and intialize the model with these hyperparameters.

# %%
# set hyperparameters for model initialization
kernel_size = [8, 4]
strides = [(2, 2)]
padding = ['same', 'valid']
pool_size = (2, 2)
pool_strides = 1

input_shape = (image_size, image_size, image_channels)
if isinstance(dense_units, int):
    dense_units = [dense_units]
num_fc_units = dense_units
dropout = [0.25, 0.25, 0.5]
embedding = None
adv_multiplier = 0.2
adv_step_size = 0.2
adv_grad_norm = 'infinity'
image_input_name = 'image'
transfer_learning = False
trainable = True

# initialize model
inputs = Input(shape=input_shape, dtype=tf.float32, name=image_input_name)
x = inputs
x = Conv2D(conv_filters[0], kernel_size=kernel_size[0], kernel_initializer='he_normal')(x)
x = Activation('relu')(x)
x = BatchNormalization()(x)
x = Conv2D(conv_filters[1], kernel_size=kernel_size[0], kernel_initializer='he_normal')(x)
x = Activation('relu')(x)
x = BatchNormalization()(x)
x = MaxPooling2D(pool_size=pool_size)(x)
x = Flatten()(x)
for num_units in num_fc_units:
    x = Dense(num_units, activation='relu')(x)
x = Activation('relu')(x)
x = BatchNormalization()(x)
x = Dense(num_classes, activation='linear', name='logits')(x)
pred = Activation('softmax', name="Softmax")(x)

# %% [markdown]
# ### Create Base Model

# %%
model_base = tf.keras.Model(inputs=inputs, outputs=pred, name="keras_generator_base")

loss = categorical_crossentropy
optimizer = Adam(learning_rate=1e-4, beta_1=1e-6)

model_base.compile(loss=loss, optimizer=optimizer, metrics=['accuracy'])

model_base.summary()
# Out:
# Model: "keras_generator_base"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  image (InputLayer)          [(None, 28, 28, 1)]       0
#
#  conv2d (Conv2D)             (None, 21, 21, 32)        2080
#
#  activation (Activation)     (None, 21, 21, 32)        0
#
#  batch_normalization (BatchN  (None, 21, 21, 32)       128
#  ormalization)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 64)        131136
#
#  activation_1 (Activation)   (None, 14, 14, 64)        0
#
#  batch_normalization_1 (Batc  (None, 14, 14, 64)       256
#  hNormalization)
#
#  max_pooling2d (MaxPooling2D  (None, 7, 7, 64)         0
#  )
#
#  flatten (Flatten)           (None, 3136)              0
#
#  dense (Dense)               (None, 1028)              3224836
#
#  activation_2 (Activation)   (None, 1028)              0
#
#  batch_normalization_2 (Batc  (None, 1028)             4112
#  hNormalization)
#
#  logits (Dense)              (None, 62)                63798
#
#  Softmax (Activation)        (None, 62)                0
#
# =================================================================
# Total params: 3,426,346
# Trainable params: 3,424,098
# Non-trainable params: 2,248
# _________________________________________________________________

# %% [markdown]
# Now, we use Keras' *model.fit* function for the given epochs to create the base model.

# %%
model_base.fit(x_base, y_base, batch_size=batch_size, epochs=EPOCHS, validation_data=(x_test, y_test))
model_base.save('model_base.h5', save_format='h5')
# Out:
# Epoch 1/20
# 1091/1091 [==============================] - 28s 14ms/step - loss: 0.7844 - accuracy: 0.7649 - val_loss: 0.5794 - val_accuracy: 0.7960
# Epoch 2/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.4753 - accuracy: 0.8376 - val_loss: 0.4995 - val_accuracy: 0.8348
# Epoch 3/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.4007 - accuracy: 0.8586 - val_loss: 0.4827 - val_accuracy: 0.8373
# Epoch 4/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.3492 - accuracy: 0.8737 - val_loss: 0.4750 - val_accuracy: 0.8382
# Epoch 5/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.3042 - accuracy: 0.8891 - val_loss: 0.4878 - val_accuracy: 0.8277
# Epoch 6/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.2628 - accuracy: 0.9030 - val_loss: 0.4848 - val_accuracy: 0.8313
# Epoch 7/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.2244 - accuracy: 0.9166 - val_loss: 0.4928 - val_accuracy: 0.8393
# Epoch 8/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.1925 - accuracy: 0.9291 - val_loss: 0.5109 - val_accuracy: 0.8272
# Epoch 9/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.1632 - accuracy: 0.9409 - val_loss: 0.5200 - val_accuracy: 0.8337
# Epoch 10/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.1409 - accuracy: 0.9498 - val_loss: 0.5568 - val_accuracy: 0.8283
# Epoch 11/20
# 1091/1091 [==============================] - 15s 13ms/step - loss: 0.1194 - accuracy: 0.9580 - val_loss: 0.5747 - val_accuracy: 0.8284
# Epoch 12/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.1024 - accuracy: 0.9646 - val_loss: 0.5934 - val_accuracy: 0.8297
# Epoch 13/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.0878 - accuracy: 0.9699 - val_loss: 0.6274 - val_accuracy: 0.8319
# Epoch 14/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.0766 - accuracy: 0.9736 - val_loss: 0.6604 - val_accuracy: 0.8226
# Epoch 15/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0649 - accuracy: 0.9784 - val_loss: 0.6718 - val_accuracy: 0.8267
# Epoch 16/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0568 - accuracy: 0.9813 - val_loss: 0.7114 - val_accuracy: 0.8248
# Epoch 17/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0482 - accuracy: 0.9846 - val_loss: 0.7490 - val_accuracy: 0.8238
# Epoch 18/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0428 - accuracy: 0.9864 - val_loss: 0.7735 - val_accuracy: 0.8202
# Epoch 19/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.0355 - accuracy: 0.9894 - val_loss: 0.7895 - val_accuracy: 0.8262
# Epoch 20/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0340 - accuracy: 0.9896 - val_loss: 0.8262 - val_accuracy: 0.8237

# %%
print('train loss and accuracy:')
train_loss_base, train_acc_base = model_base.evaluate(x_base, y_base, verbose=1, steps=batch_size+1)

print('test loss and accuracy:')
test_loss_base, test_acc_base = model_base.evaluate(x_test, y_test, verbose=1, steps=batch_size+1)

print('per class reports:')
report_base = classification_report(np.argmax(y_test, axis=1), np.argmax(model_base.predict((x_test)), axis=1),
                               output_dict=True)
for key,value in report_base.items():
	print(key, ':', value)
# Out:
# train loss and accuracy:
# 129/129 [==============================] - 3s 18ms/step - loss: 0.0242 - accuracy: 0.9936
# test loss and accuracy:
# 129/129 [==============================] - 2s 15ms/step - loss: 0.8262 - accuracy: 0.8237
# per class reports:
# 3636/3636 [==============================] - 7s 2ms/step
# 0 : {'precision': 0.6694295465626524, 'recall': 0.7128764278296988, 'f1-score': 0.6904702036711089, 'support': 5778}
# 1 : {'precision': 0.6882964698989307, 'recall': 0.7423380726698262, 'f1-score': 0.7142965721669072, 'support': 6330}
# 2 : {'precision': 0.9404983895575522, 'recall': 0.9453058442664849, 'f1-score': 0.9428959891230455, 'support': 5869}
# 3 : {'precision': 0.9841457244054647, 'recall': 0.9775506785056123, 'f1-score': 0.9808371154815936, 'support': 5969}
# 4 : {'precision': 0.9410633088492479, 'recall': 0.9576437088449902, 'f1-score': 0.9492811149334038, 'support': 5619}
# 5 : {'precision': 0.9171259842519685, 'recall': 0.8976878612716763, 'f1-score': 0.9073028237585199, 'support': 5190}
# 6 : {'precision': 0.9441407584557567, 'recall': 0.9687992988606485, 'f1-score': 0.956311099576088, 'support': 5705}
# 7 : {'precision': 0.9726027397260274, 'recall': 0.9830591301514905, 'f1-score': 0.977802981205444, 'support': 6139}
# 8 : {'precision': 0.956928508384819, 'recall': 0.9623646369607669, 'f1-score': 0.9596388741370153, 'support': 5633}
# 9 : {'precision': 0.908246225319396, 'recall': 0.9627154414351038, 'f1-score': 0.9346879535558781, 'support': 5686}
# 10 : {'precision': 0.8757875787578758, 'recall': 0.916195856873823, 'f1-score': 0.8955361251725725, 'support': 1062}
# 11 : {'precision': 0.8870151770657673, 'recall': 0.8117283950617284, 'f1-score': 0.8477034649476229, 'support': 648}
# 12 : {'precision': 0.7745856353591161, 'recall': 0.8062104657849338, 'f1-score': 0.7900817131586363, 'support': 1739}
# 13 : {'precision': 0.8038461538461539, 'recall': 0.8048780487804879, 'f1-score': 0.8043617703656191, 'support': 779}
# 14 : {'precision': 0.9306569343065694, 'recall': 0.8989424206815512, 'f1-score': 0.9145248057381948, 'support': 851}
# 15 : {'precision': 0.7571428571428571, 'recall': 0.8097222222222222, 'f1-score': 0.7825503355704698, 'support': 1440}
# 16 : {'precision': 0.8740359897172236, 'recall': 0.7606263982102909, 'f1-score': 0.8133971291866028, 'support': 447}
# 17 : {'precision': 0.8609523809523809, 'recall': 0.8675623800383877, 'f1-score': 0.8642447418738048, 'support': 521}
# 18 : {'precision': 0.47731755424063116, 'recall': 0.47265625, 'f1-score': 0.47497546614327774, 'support': 2048}
# 19 : {'precision': 0.8451730418943534, 'recall': 0.7412140575079872, 'f1-score': 0.7897872340425532, 'support': 626}
# 20 : {'precision': 0.5869565217391305, 'recall': 0.6361256544502618, 'f1-score': 0.6105527638190956, 'support': 382}
# 21 : {'precision': 0.8484500574052812, 'recall': 0.9123456790123456, 'f1-score': 0.8792385484830458, 'support': 810}
# 22 : {'precision': 0.7488235294117647, 'recall': 0.8572390572390572, 'f1-score': 0.7993720565149137, 'support': 1485}
# 23 : {'precision': 0.9112903225806451, 'recall': 0.920059215396003, 'f1-score': 0.9156537753222836, 'support': 1351}
# 24 : {'precision': 0.5800441284628586, 'recall': 0.5692974013474494, 'f1-score': 0.5746205221615058, 'support': 4156}
# 25 : {'precision': 0.786896095301125, 'recall': 0.851109520400859, 'f1-score': 0.8177441540577716, 'support': 1397}
# 26 : {'precision': 0.8659217877094972, 'recall': 0.7506053268765133, 'f1-score': 0.8041504539559013, 'support': 413}
# 27 : {'precision': 0.879021879021879, 'recall': 0.8442521631644005, 'f1-score': 0.8612862547288778, 'support': 809}
# 28 : {'precision': 0.7769449470147325, 'recall': 0.8568985176738882, 'f1-score': 0.8149654331028874, 'support': 3508}
# 29 : {'precision': 0.9050031665611147, 'recall': 0.9067258883248731, 'f1-score': 0.905863708399366, 'support': 1576}
# 30 : {'precision': 0.7485029940119761, 'recall': 0.8741258741258742, 'f1-score': 0.8064516129032258, 'support': 2002}
# 31 : {'precision': 0.6176084099868594, 'recall': 0.5904522613065326, 'f1-score': 0.6037251123956325, 'support': 796}
# 32 : {'precision': 0.6740597878495661, 'recall': 0.8672456575682382, 'f1-score': 0.75854584915898, 'support': 806}
# 33 : {'precision': 0.631578947368421, 'recall': 0.6666666666666666, 'f1-score': 0.6486486486486486, 'support': 432}
# 34 : {'precision': 0.7031700288184438, 'recall': 0.6115288220551378, 'f1-score': 0.6541554959785522, 'support': 798}
# 35 : {'precision': 0.6004140786749482, 'recall': 0.625, 'f1-score': 0.6124604012671595, 'support': 464}
# 36 : {'precision': 0.8523809523809524, 'recall': 0.8710462287104623, 'f1-score': 0.8616125150421179, 'support': 1644}
# 37 : {'precision': 0.8368700265251989, 'recall': 0.7397420867526378, 'f1-score': 0.7853142501555693, 'support': 853}
# 38 : {'precision': 0.27715355805243447, 'recall': 0.1712962962962963, 'f1-score': 0.21173104434907014, 'support': 432}
# 39 : {'precision': 0.9305153445280834, 'recall': 0.9548425430778372, 'f1-score': 0.9425219941348973, 'support': 1683}
# 40 : {'precision': 0.9447069943289225, 'recall': 0.97702834799609, 'f1-score': 0.9605958673714561, 'support': 4092}
# 41 : {'precision': 0.3484848484848485, 'recall': 0.23, 'f1-score': 0.27710843373493976, 'support': 400}
# 42 : {'precision': 0.5462962962962963, 'recall': 0.400679117147708, 'f1-score': 0.4622918707149853, 'support': 589}
# 43 : {'precision': 0.9338387319090282, 'recall': 0.9161595672751859, 'f1-score': 0.9249146757679181, 'support': 1479}
# 44 : {'precision': 0.6607142857142857, 'recall': 0.34660421545667447, 'f1-score': 0.45468509984639016, 'support': 427}
# 45 : {'precision': 0.6296296296296297, 'recall': 0.6435331230283912, 'f1-score': 0.6365054602184087, 'support': 317}
# 46 : {'precision': 0.6323185011709602, 'recall': 0.5793991416309013, 'f1-score': 0.6047032474804032, 'support': 466}
# 47 : {'precision': 0.3529941467807294, 'recall': 0.30927021696252466, 'f1-score': 0.3296888141295206, 'support': 2535}
# 48 : {'precision': 0.3664383561643836, 'recall': 0.23060344827586207, 'f1-score': 0.2830687830687831, 'support': 464}
# 49 : {'precision': 0.928915018706574, 'recall': 0.9157007376185459, 'f1-score': 0.9222605465640753, 'support': 1898}
# 50 : {'precision': 0.12903225806451613, 'recall': 0.05150214592274678, 'f1-score': 0.0736196319018405, 'support': 466}
# 51 : {'precision': 0.377431906614786, 'recall': 0.26358695652173914, 'f1-score': 0.3104, 'support': 368}
# 52 : {'precision': 0.5224913494809689, 'recall': 0.299009900990099, 'f1-score': 0.380352644836272, 'support': 505}
# 53 : {'precision': 0.9493287137288869, 'recall': 0.9448275862068966, 'f1-score': 0.9470728019010586, 'support': 2320}
# 54 : {'precision': 0.1206896551724138, 'recall': 0.04805491990846682, 'f1-score': 0.06873977086743044, 'support': 437}
# 55 : {'precision': 0.889315419065899, 'recall': 0.9376053962900506, 'f1-score': 0.9128221966836316, 'support': 2965}
# 56 : {'precision': 0.2857142857142857, 'recall': 0.13692946058091288, 'f1-score': 0.18513323983169705, 'support': 482}
# 57 : {'precision': 0.43043478260869567, 'recall': 0.4230769230769231, 'f1-score': 0.42672413793103453, 'support': 468}
# 58 : {'precision': 0.6872427983539094, 'recall': 0.3576017130620985, 'f1-score': 0.4704225352112676, 'support': 467}
# 59 : {'precision': 0.6717171717171717, 'recall': 0.5659574468085107, 'f1-score': 0.6143187066974596, 'support': 470}
# 60 : {'precision': 0.4053156146179402, 'recall': 0.32020997375328086, 'f1-score': 0.3577712609970674, 'support': 381}
# 61 : {'precision': 0.5333333333333333, 'recall': 0.4611973392461197, 'f1-score': 0.4946492271105826, 'support': 451}
# accuracy : 0.8236978069685272
# macro avg : {'precision': 0.7115642196735179, 'recall': 0.6844390344219802, 'f1-score': 0.6928572751815176, 'support': 116323}
# weighted avg : {'precision': 0.8145840857164995, 'recall': 0.8236978069685272, 'f1-score': 0.8174562165646386, 'support': 116323}

# %% [markdown]
# ### Create Production Model

# %% [markdown]
# Next, we train our production model with the partitioned production data.

# %%
model_production = tf.keras.models.load_model('model_base.h5')

model_production.fit(x_production, y_production, batch_size=batch_size, epochs=EPOCHS, validation_data=(x_test, y_test))
model_production.save('model_production.h5', save_format='h5')
# Out:
# Epoch 1/20
# 1091/1091 [==============================] - 17s 14ms/step - loss: 0.5689 - accuracy: 0.8258 - val_loss: 0.4667 - val_accuracy: 0.8401
# Epoch 2/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.3500 - accuracy: 0.8723 - val_loss: 0.4614 - val_accuracy: 0.8446
# Epoch 3/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.2873 - accuracy: 0.8920 - val_loss: 0.4763 - val_accuracy: 0.8401
# Epoch 4/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.2330 - accuracy: 0.9116 - val_loss: 0.4842 - val_accuracy: 0.8427
# Epoch 5/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.1894 - accuracy: 0.9289 - val_loss: 0.5077 - val_accuracy: 0.8428
# Epoch 6/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.1528 - accuracy: 0.9444 - val_loss: 0.5296 - val_accuracy: 0.8400
# Epoch 7/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.1256 - accuracy: 0.9548 - val_loss: 0.5572 - val_accuracy: 0.8383
# Epoch 8/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.1019 - accuracy: 0.9647 - val_loss: 0.5855 - val_accuracy: 0.8343
# Epoch 9/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0820 - accuracy: 0.9729 - val_loss: 0.6205 - val_accuracy: 0.8345
# Epoch 10/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.0670 - accuracy: 0.9784 - val_loss: 0.6580 - val_accuracy: 0.8313
# Epoch 11/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0554 - accuracy: 0.9820 - val_loss: 0.6833 - val_accuracy: 0.8296
# Epoch 12/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.0452 - accuracy: 0.9861 - val_loss: 0.7147 - val_accuracy: 0.8305
# Epoch 13/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.0381 - accuracy: 0.9884 - val_loss: 0.7688 - val_accuracy: 0.8232
# Epoch 14/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0303 - accuracy: 0.9915 - val_loss: 0.7713 - val_accuracy: 0.8287
# Epoch 15/20
# 1091/1091 [==============================] - 14s 13ms/step - loss: 0.0252 - accuracy: 0.9933 - val_loss: 0.8174 - val_accuracy: 0.8261
# Epoch 16/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0231 - accuracy: 0.9938 - val_loss: 0.8242 - val_accuracy: 0.8240
# Epoch 17/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0194 - accuracy: 0.9951 - val_loss: 0.8502 - val_accuracy: 0.8268
# Epoch 18/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0153 - accuracy: 0.9964 - val_loss: 0.8762 - val_accuracy: 0.8248
# Epoch 19/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0181 - accuracy: 0.9954 - val_loss: 0.8847 - val_accuracy: 0.8280
# Epoch 20/20
# 1091/1091 [==============================] - 12s 11ms/step - loss: 0.0133 - accuracy: 0.9969 - val_loss: 0.9260 - val_accuracy: 0.8228

# %%
print('production train loss and accuracy:')
train_loss_production, train_acc_production = model_production.evaluate(x_production, y_production, verbose=1, steps=batch_size+1)

print('production test loss and accuracy:')
test_loss_production, test_acc_production = model_production.evaluate(x_test, y_test, verbose=1, steps=batch_size+1)

print('production per class reports:')
report_production = classification_report(np.argmax(y_test, axis=1), np.argmax(model_production.predict((x_test)), axis=1),
                               output_dict=True)
for key,value in report_production.items():
	print(key, ':', value)
# Out:
# production train loss and accuracy:
# 129/129 [==============================] - 2s 18ms/step - loss: 0.0167 - accuracy: 0.9959
# production test loss and accuracy:
# 129/129 [==============================] - 2s 12ms/step - loss: 0.9260 - accuracy: 0.8228
# production per class reports:
# 3636/3636 [==============================] - 8s 2ms/step
# 0 : {'precision': 0.6455496631790167, 'recall': 0.7795084804430599, 'f1-score': 0.7062328498627989, 'support': 5778}
# 1 : {'precision': 0.6763690922730683, 'recall': 0.7121642969984202, 'f1-score': 0.6938053097345132, 'support': 6330}
# 2 : {'precision': 0.9364307279436431, 'recall': 0.9512693814959959, 'f1-score': 0.9437917335812696, 'support': 5869}
# 3 : {'precision': 0.9855728904546217, 'recall': 0.984251968503937, 'f1-score': 0.9849119865884326, 'support': 5969}
# 4 : {'precision': 0.9532111723892546, 'recall': 0.9535504538174052, 'f1-score': 0.9533807829181494, 'support': 5619}
# 5 : {'precision': 0.8661319073083779, 'recall': 0.936223506743738, 'f1-score': 0.8998148148148147, 'support': 5190}
# 6 : {'precision': 0.9559052394950718, 'recall': 0.9689745836985101, 'f1-score': 0.9623955431754874, 'support': 5705}
# 7 : {'precision': 0.9740990990990991, 'recall': 0.9863169897377423, 'f1-score': 0.9801699716713881, 'support': 6139}
# 8 : {'precision': 0.956194147538111, 'recall': 0.9687555476655424, 'f1-score': 0.9624338624338624, 'support': 5633}
# 9 : {'precision': 0.9123892325698044, 'recall': 0.9597256419275413, 'f1-score': 0.935458986886089, 'support': 5686}
# 10 : {'precision': 0.8811438784629133, 'recall': 0.928436911487759, 'f1-score': 0.9041723979825768, 'support': 1062}
# 11 : {'precision': 0.900990099009901, 'recall': 0.8425925925925926, 'f1-score': 0.8708133971291866, 'support': 648}
# 12 : {'precision': 0.7674678591391839, 'recall': 0.78953421506613, 'f1-score': 0.778344671201814, 'support': 1739}
# 13 : {'precision': 0.7936893203883495, 'recall': 0.8395378690629012, 'f1-score': 0.8159700561447286, 'support': 779}
# 14 : {'precision': 0.9425149700598803, 'recall': 0.9247943595769683, 'f1-score': 0.933570581257414, 'support': 851}
# 15 : {'precision': 0.7709720372836218, 'recall': 0.8041666666666667, 'f1-score': 0.7872195785180149, 'support': 1440}
# 16 : {'precision': 0.8917525773195877, 'recall': 0.7740492170022372, 'f1-score': 0.8287425149700599, 'support': 447}
# 17 : {'precision': 0.8846880907372401, 'recall': 0.8982725527831094, 'f1-score': 0.8914285714285713, 'support': 521}
# 18 : {'precision': 0.49286498353457736, 'recall': 0.4384765625, 'f1-score': 0.46408268733850133, 'support': 2048}
# 19 : {'precision': 0.8184764991896273, 'recall': 0.8067092651757188, 'f1-score': 0.8125502815768302, 'support': 626}
# 20 : {'precision': 0.6005434782608695, 'recall': 0.5785340314136126, 'f1-score': 0.5893333333333333, 'support': 382}
# 21 : {'precision': 0.8814814814814815, 'recall': 0.8814814814814815, 'f1-score': 0.8814814814814815, 'support': 810}
# 22 : {'precision': 0.7589556769884639, 'recall': 0.8417508417508418, 'f1-score': 0.7982120051085568, 'support': 1485}
# 23 : {'precision': 0.9031117397454032, 'recall': 0.9452257586972613, 'f1-score': 0.9236889692585897, 'support': 1351}
# 24 : {'precision': 0.6012880562060889, 'recall': 0.49422521655437923, 'f1-score': 0.5425250924458531, 'support': 4156}
# 25 : {'precision': 0.8211624441132638, 'recall': 0.7888332140300645, 'f1-score': 0.8046732384081782, 'support': 1397}
# 26 : {'precision': 0.8186157517899761, 'recall': 0.8305084745762712, 'f1-score': 0.8245192307692308, 'support': 413}
# 27 : {'precision': 0.8968553459119497, 'recall': 0.8813349814585909, 'f1-score': 0.8890274314214464, 'support': 809}
# 28 : {'precision': 0.8097277454879168, 'recall': 0.7545610034207526, 'f1-score': 0.7811716098568688, 'support': 3508}
# 29 : {'precision': 0.8915211970074813, 'recall': 0.9073604060913706, 'f1-score': 0.89937106918239, 'support': 1576}
# 30 : {'precision': 0.7463153193389906, 'recall': 0.8346653346653347, 'f1-score': 0.7880216929969348, 'support': 2002}
# 31 : {'precision': 0.6253521126760564, 'recall': 0.5577889447236181, 'f1-score': 0.5896414342629482, 'support': 796}
# 32 : {'precision': 0.7664907651715039, 'recall': 0.7208436724565757, 'f1-score': 0.7429667519181584, 'support': 806}
# 33 : {'precision': 0.7383512544802867, 'recall': 0.47685185185185186, 'f1-score': 0.579465541490858, 'support': 432}
# 34 : {'precision': 0.6814044213263979, 'recall': 0.656641604010025, 'f1-score': 0.6687938736439055, 'support': 798}
# 35 : {'precision': 0.5846456692913385, 'recall': 0.6400862068965517, 'f1-score': 0.611111111111111, 'support': 464}
# 36 : {'precision': 0.8687306501547988, 'recall': 0.8534063260340633, 'f1-score': 0.8610003068425898, 'support': 1644}
# 37 : {'precision': 0.8235294117647058, 'recall': 0.8042203985932005, 'f1-score': 0.8137603795966786, 'support': 853}
# 38 : {'precision': 0.28609625668449196, 'recall': 0.24768518518518517, 'f1-score': 0.2655086848635236, 'support': 432}
# 39 : {'precision': 0.9242165242165242, 'recall': 0.9637551990493167, 'f1-score': 0.9435718440954044, 'support': 1683}
# 40 : {'precision': 0.9625850340136054, 'recall': 0.9682306940371457, 'f1-score': 0.9653996101364521, 'support': 4092}
# 41 : {'precision': 0.35135135135135137, 'recall': 0.26, 'f1-score': 0.2988505747126437, 'support': 400}
# 42 : {'precision': 0.5656108597285068, 'recall': 0.4244482173174873, 'f1-score': 0.48496605237633367, 'support': 589}
# 43 : {'precision': 0.9373709566414316, 'recall': 0.920892494929006, 'f1-score': 0.9290586630286495, 'support': 1479}
# 44 : {'precision': 0.5741444866920152, 'recall': 0.35362997658079626, 'f1-score': 0.43768115942028984, 'support': 427}
# 45 : {'precision': 0.6587837837837838, 'recall': 0.6151419558359621, 'f1-score': 0.6362153344208809, 'support': 317}
# 46 : {'precision': 0.6126315789473684, 'recall': 0.6244635193133047, 'f1-score': 0.6184909670563231, 'support': 466}
# 47 : {'precision': 0.3319099378881988, 'recall': 0.33727810650887574, 'f1-score': 0.33457249070631967, 'support': 2535}
# 48 : {'precision': 0.33666666666666667, 'recall': 0.21767241379310345, 'f1-score': 0.2643979057591623, 'support': 464}
# 49 : {'precision': 0.9376017362995117, 'recall': 0.9104320337197049, 'f1-score': 0.9238171611868485, 'support': 1898}
# 50 : {'precision': 0.06741573033707865, 'recall': 0.012875536480686695, 'f1-score': 0.021621621621621623, 'support': 466}
# 51 : {'precision': 0.39540816326530615, 'recall': 0.421195652173913, 'f1-score': 0.4078947368421052, 'support': 368}
# 52 : {'precision': 0.5172413793103449, 'recall': 0.297029702970297, 'f1-score': 0.37735849056603776, 'support': 505}
# 53 : {'precision': 0.9516129032258065, 'recall': 0.940948275862069, 'f1-score': 0.9462505418292155, 'support': 2320}
# 54 : {'precision': 0.14339622641509434, 'recall': 0.08695652173913043, 'f1-score': 0.10826210826210826, 'support': 437}
# 55 : {'precision': 0.9115874079035499, 'recall': 0.918043844856661, 'f1-score': 0.914804234582423, 'support': 2965}
# 56 : {'precision': 0.2724014336917563, 'recall': 0.15767634854771784, 'f1-score': 0.19973718791064388, 'support': 482}
# 57 : {'precision': 0.41767068273092367, 'recall': 0.4444444444444444, 'f1-score': 0.4306418219461698, 'support': 468}
# 58 : {'precision': 0.6168958742632613, 'recall': 0.6723768736616702, 'f1-score': 0.6434426229508197, 'support': 467}
# 59 : {'precision': 0.6076388888888888, 'recall': 0.7446808510638298, 'f1-score': 0.6692160611854684, 'support': 470}
# 60 : {'precision': 0.40594059405940597, 'recall': 0.3228346456692913, 'f1-score': 0.35964912280701755, 'support': 381}
# 61 : {'precision': 0.5668604651162791, 'recall': 0.43237250554323725, 'f1-score': 0.49056603773584906, 'support': 451}
# accuracy : 0.8228467285059704
# macro avg : {'precision': 0.7125408859789206, 'recall': 0.693398319531204, 'f1-score': 0.6995166156184826, 'support': 116323}
# weighted avg : {'precision': 0.8154208640699634, 'recall': 0.8228467285059704, 'f1-score': 0.8175808769586422, 'support': 116323}

# %% [markdown]
# ## Gray Data Generation
# The next step in our model drift detection pipeline is to run a model inversion attack on the base and production models and create gray data from both.

# %% [markdown]
# First, let's import everything we need to run the model inversion and generate the gray data.

# %%
# GrayDataGenerator imports
from __future__ import absolute_import, division, print_function, unicode_literals
from typing import Optional, TYPE_CHECKING
from tqdm import trange
from tensorflow import keras
from art.estimators.classification.classifier import ClassifierMixin, ClassGradientsMixin
from art.estimators.estimator import BaseEstimator
from art.attacks.attack import InferenceAttack
from art.utils import get_labels_np_array, check_and_transform_label_format
if TYPE_CHECKING:
    from art.utils import CLASSIFIER_CLASS_LOSS_GRADIENTS_TYPE

# model inversion
from art.estimators.classification import TensorFlowV2Classifier
from tensorflow.keras.losses import CategoricalCrossentropy

# %% [markdown]
# ### **GrayDataGenerator** Class
# To create the gray data, we first need to port the [MIFace implementation from the Adversarial Robustness Toolbox](https://github.com/Trusted-AI/adversarial-robustness-toolbox/blob/main/art/attacks/inference/model_inversion/mi_face.py) into our example. However, we cannot just import this class because there are a few things that we have changed to work in our test case, so we rename the class **GrayDataGenerator**.
#
# Running the following code section will port that class to our example:

# %%
class GrayDataGenerator(InferenceAttack):

    attack_params = InferenceAttack.attack_params + [
        "max_iter",
        "window_length",
        "threshold",
        "learning_rate",
        "batch_size",
        "verbose",
    ]

    _estimator_requirements = (BaseEstimator, ClassifierMixin, ClassGradientsMixin)

    def __init__(
            self,
            classifier: "CLASSIFIER_CLASS_LOSS_GRADIENTS_TYPE",
            max_iter: int = 10000,
            window_length: int = 100,
            threshold: float = 0.99,
            learning_rate: float = 0.1,
            batch_size: int = 1,
            verbose: bool = True,
            g_size: int = 100,
    ):

        super().__init__(estimator=classifier)

        self.max_iter = max_iter
        self.window_length = window_length
        self.threshold = threshold
        self.learning_rate = learning_rate
        self.batch_size = batch_size
        self.verbose = verbose
        self.g_size = g_size

    def infer(self, x: Optional[np.ndarray], y: Optional[np.ndarray] = None, k_model=None, **kwargs) -> np.ndarray:
        if x is None and y is None:
            raise ValueError("Either `x` or `y` should be provided.")

        y = check_and_transform_label_format(y, self.estimator.nb_classes)
        if x is None:
            x = np.zeros((len(y),) + self.estimator.input_shape)
        if y is None:
            y = get_labels_np_array(self.estimator.predict(x, batch_size=self.batch_size))

        x_infer = x.astype(np.float32)
        gray_x = []
        gray_y = []

        # Compute inversions with implicit batching
        for batch_id in trange(
                int(np.ceil(x.shape[0] / float(self.batch_size))), desc="Model inversion", disable=not self.verbose
        ):
            batch_index_1, batch_index_2 = batch_id * self.batch_size, (batch_id + 1) * self.batch_size
            batch = x_infer[batch_index_1:batch_index_2]
            batch_labels = y[batch_index_1:batch_index_2]

            active = np.array([True] * len(batch))
            window = np.inf * np.ones((len(batch), self.window_length))

            i = 0
            acc = False
            g_num = 0

            while i < self.max_iter and sum(active) > 0 and g_num < self.g_size:
                grads = self.estimator.class_gradient(batch[active], np.argmax(batch_labels[active], axis=1))
                grads = np.reshape(grads, (grads.shape[0],) + grads.shape[2:])
                batch[active] = batch[active] + self.learning_rate * grads

                if self.estimator.clip_values is not None:
                    clip_min, clip_max = self.estimator.clip_values
                    batch[active] = np.clip(batch[active], clip_min, clip_max)

                cost = 1 - self.estimator.predict(batch)[np.arange(len(batch)), np.argmax(batch_labels, axis=1)]
                active = (cost <= self.threshold) + (cost >= np.max(window, axis=1))

                i_window = i % self.window_length
                window[::, i_window] = cost
                i = i + 1

                if acc:
                    if image_channels == 1:
                        x = np.reshape(batch, (image_size, image_size, 1))
                    gray_x.append(x)
                    gray_y.append(batch_index_1)
                    g_num = g_num + 1
                else:
                    new_gray = keras.utils.to_categorical(np.array([batch_index_1]), num_classes)
                    scores = k_model.evaluate(batch, new_gray, verbose=1)
                    if int(scores[1] == 1):
                        acc = True
                        x = np.reshape(batch, (image_size, image_size, image_channels))
                        gray_x.append(x)
                        gray_y.append(batch_index_1)
                        g_num = g_num + 1
            x_infer[batch_index_1:batch_index_2] = batch

        return np.array(gray_x), np.array(gray_y)

# %% [markdown]
# ### Model Inversion Attack

# %% [markdown]
# Now we use the **GrayDataGenerator** class to run the model inversion against the base model to create the "base" gray data.

# %%
restore_model_base = tf.keras.models.load_model('model_base.h5')
loss_object = CategoricalCrossentropy(from_logits=True)

krc_base = TensorFlowV2Classifier(
    model=restore_model_base,
    nb_classes=num_classes,
    loss_object=loss_object,
    input_shape=(image_size, image_size, image_channels),
    clip_values=(0, 1),
)

attack_base = GrayDataGenerator(krc_base, max_iter=60, threshold=1., batch_size=1, g_size=100)

x_init_average = np.zeros((num_classes, image_size, image_size, image_channels)) + np.mean(x_test, axis=0)
y_gray_base = np.arange(num_classes)
class_gradient = krc_base.class_gradient(x_init_average, y_gray_base)
class_gradient = np.reshape(class_gradient, (num_classes, image_size * image_size, image_channels))
class_gradient_max = np.max(class_gradient, axis=1)

print("Minimum over all maximum class gradient: %f" % (np.min(class_gradient_max)))
# Out:
# WARNING:tensorflow:Calling GradientTape.gradient on a persistent tape inside its context is significantly less efficient than calling it outside the context (it causes the gradient ops to be recorded on the tape, leading to increased CPU and memory usage). Only call GradientTape.gradient inside the context if you actually want to trace the gradient in order to compute higher order derivatives.
# Minimum over all maximum class gradient: 0.000000

# %% [markdown]
# To ensure that the gray data is recognizable by the base model, we reevaluate the base model with the new gray data. (This step should take ~5 min if you are running on a GPU.)

# %%
x_gray_base, y_gray_base = attack_base.infer(x_init_average, y_gray_base, restore_model_base)
y_gray_base = keras.utils.to_categorical(np.array(y_gray_base), num_classes)

print('\n gray data loss and accuracy based on base model:')
scores_gray_base = restore_model_base.evaluate(x_gray_base, y_gray_base, verbose=1)
# Out:
# Model inversion:   0%|          | 0/62 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 234ms/step - loss: 14.6382 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6380 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6379 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6377 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.6375 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.6374 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 14.6372 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6370 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6369 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6367 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 14.6366 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6364 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 14.6362 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6361 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 14.6359 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6357 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 14.6356 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.6354 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 14.6352 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6351 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6349 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 14.6347 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6346 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6344 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6341 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.6339 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6337 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6336 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.6334 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6332 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.6331 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6329 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 14.6328 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6326 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.6324 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6323 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6321 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.6319 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 14.6318 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 14.6316 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.6314 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.6313 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6311 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6309 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6308 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6306 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.6304 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6303 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 14.6301 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6299 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6298 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.6296 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6294 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 14.6293 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.6291 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.6290 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6288 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.6286 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.6285 - accuracy: 0.0000e+00
# Model inversion:   2%|▏         | 1/62 [00:06<06:08,  6.05s/it]
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0028 - accuracy: 1.0000
# Model inversion:   3%|▎         | 2/62 [00:07<03:23,  3.39s/it]
# 1/1 [==============================] - 0s 29ms/step - loss: 12.1733 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1717 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.1700 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.1684 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1667 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.1651 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.1635 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.1618 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1602 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.1585 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.1569 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1552 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.1536 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.1519 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.1502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1486 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.1469 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.1452 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.1436 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1419 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1402 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.1385 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 48ms/step - loss: 12.1369 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.1352 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 12.1335 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.1318 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 12.1301 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 12.1284 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.1267 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 12.1251 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.1234 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 12.1217 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 42ms/step - loss: 12.1200 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.1183 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 12.1166 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.1148 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.1131 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.1114 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 60ms/step - loss: 12.1096 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.1079 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.1062 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.1044 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1026 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1009 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.0991 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.0974 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.0956 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.0938 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.0920 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.0903 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.0885 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.0867 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.0849 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.0831 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.0813 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.0795 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.0777 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.0759 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.0741 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.0723 - accuracy: 0.0000e+00
# Model inversion:   5%|▍         | 3/62 [00:13<04:41,  4.77s/it]
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 49ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.3860 - accuracy: 0.0000e+00
# Model inversion:   6%|▋         | 4/62 [00:20<05:05,  5.27s/it]
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 51ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 23ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 42.0779 - accuracy: 0.0000e+00
# Model inversion:   8%|▊         | 5/62 [00:26<05:24,  5.68s/it]
# 1/1 [==============================] - 0s 26ms/step - loss: 9.0222 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 8.9867 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.9505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.9131 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 8.8746 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.8345 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.7929 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 8.7498 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 8.7053 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.6598 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 8.6121 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.5622 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 8.5078 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 8.4505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 8.3915 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.3296 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 8.2616 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.1894 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 8.1137 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 8.0346 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 7.9500 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 7.8586 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 7.7591 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 7.6478 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 7.5215 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 7.3810 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 7.2263 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 7.0468 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 6.8321 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 6.5666 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 6.2574 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 5.8631 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 5.3034 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 4.3760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 2.4942 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 0.0024 - accuracy: 1.0000
# Model inversion:  10%|▉         | 6/62 [00:30<04:44,  5.09s/it]
# 1/1 [==============================] - 0s 28ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 23ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 23ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 48ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 22.5760 - accuracy: 0.0000e+00
# Model inversion:  11%|█▏        | 7/62 [00:36<05:00,  5.46s/it]
# 1/1 [==============================] - 0s 53ms/step - loss: 17.0509 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 17.0509 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 17.0509 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 42ms/step - loss: 17.0509 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0508 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 17.0507 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 17.0506 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0505 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 17.0504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0503 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 17.0502 - accuracy: 0.0000e+00
# Model inversion:  13%|█▎        | 8/62 [00:42<05:03,  5.62s/it]
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 23ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 55ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 55ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 45ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 24.9342 - accuracy: 0.0000e+00
# Model inversion:  15%|█▍        | 9/62 [00:48<05:05,  5.76s/it]
# 1/1 [==============================] - 0s 36ms/step - loss: 12.9111 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.9103 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.9095 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 12.9087 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 46ms/step - loss: 12.9079 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 12.9071 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 12.9064 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.9056 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.9048 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.9040 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.9032 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.9024 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.9016 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.9008 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.9000 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8992 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8984 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8977 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.8969 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8961 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8953 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8945 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8937 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8929 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8921 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8913 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8905 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.8897 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.8889 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8881 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.8873 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.8865 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8856 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.8848 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8840 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.8831 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.8823 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.8815 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.8807 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8798 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8790 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8782 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8773 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8765 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.8757 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8748 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8740 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8732 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.8723 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8715 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8707 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8698 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8690 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8681 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8673 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8665 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8656 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.8648 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8639 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.8631 - accuracy: 0.0000e+00
# Model inversion:  16%|█▌        | 10/62 [00:54<05:05,  5.88s/it]
# 1/1 [==============================] - 0s 26ms/step - loss: 31.5834 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 31.5834 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 31.5834 - accuracy: 0.0000e+00
# ...
# 1/1 [==============================] - 0s 28ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 19.5947 - accuracy: 0.0000e+00
# Model inversion:  97%|█████████▋| 60/62 [05:49<00:12,  6.02s/it]
# 1/1 [==============================] - 0s 29ms/step - loss: 13.4190 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 13.4186 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 13.4182 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.4177 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 13.4173 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 13.4169 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 13.4165 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 13.4161 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 13.4157 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 13.4152 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 13.4148 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 13.4144 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 13.4140 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 13.4136 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 46ms/step - loss: 13.4132 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 47ms/step - loss: 13.4127 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 13.4123 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 13.4119 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 13.4115 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 13.4111 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 13.4106 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 13.4102 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 13.4098 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 13.4094 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 13.4090 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 13.4085 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 13.4081 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 13.4077 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 13.4073 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 13.4068 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 13.4064 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 13.4060 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 13.4056 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 13.4052 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 13.4047 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 13.4043 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 13.4039 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 13.4035 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 13.4031 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.4026 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 13.4022 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 13.4018 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 13.4014 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.4009 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 13.4005 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.4001 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 13.3997 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 13.3992 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 13.3988 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 13.3984 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.3980 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.3976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 13.3971 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 13.3967 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.3963 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.3959 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 13.3954 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 13.3950 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 13.3946 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 13.3942 - accuracy: 0.0000e+00
# Model inversion:  98%|█████████▊| 61/62 [05:56<00:06,  6.27s/it]
# 1/1 [==============================] - 0s 34ms/step - loss: 10.0073 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 9.9956 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 9.9838 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.9719 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.9598 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 9.9477 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.9355 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 9.9231 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.9106 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.8981 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.8853 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.8725 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 9.8594 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 9.8465 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 9.8335 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 9.8204 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.8072 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.7939 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.7804 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.7668 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 9.7532 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.7393 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 9.7253 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.7111 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 9.6968 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 9.6822 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 9.6675 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.6526 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.6374 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.6221 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 9.6067 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 9.5911 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.5754 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 9.5598 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.5440 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.5280 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.5119 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 9.4954 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 9.4788 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.4619 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 9.4447 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.4272 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.4095 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 9.3914 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 9.3731 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 9.3546 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 9.3358 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.3167 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 9.2973 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.2775 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.2573 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.2364 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.2151 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 9.1934 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 9.1710 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 9.1480 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 9.1245 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 9.1011 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 9.0771 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 9.0526 - accuracy: 0.0000e+00
# Model inversion: 100%|██████████| 62/62 [06:02<00:00,  5.85s/it]
#  gray data loss and accuracy based on base model:
# 14/14 [==============================] - 0s 9ms/step - loss: 1.1373e-04 - accuracy: 1.0000

# %% [markdown]
# Let's do the same for the production model.

# %%
restore_model_production = tf.keras.models.load_model('model_production.h5')
loss_object = CategoricalCrossentropy(from_logits=True)

krc_production = TensorFlowV2Classifier(
    model=restore_model_production,
    nb_classes=num_classes,
    loss_object=loss_object,
    input_shape=(image_size, image_size, image_channels),
    clip_values=(0, 1),
)

attack_production = GrayDataGenerator(krc_production, max_iter=60, threshold=1., batch_size=1, g_size=100)

x_init_average = np.zeros((num_classes, image_size, image_size, image_channels)) + np.mean(x_test, axis=0)
y_gray_production = np.arange(num_classes)
class_gradient = krc_production.class_gradient(x_init_average, y_gray_production)
class_gradient = np.reshape(class_gradient, (num_classes, image_size * image_size, image_channels))
class_gradient_max = np.max(class_gradient, axis=1)

print("Minimum over all maximum class gradient: %f" % (np.min(class_gradient_max)))
# Out:
# Minimum over all maximum class gradient: 0.000000

# %% [markdown]
# To ensure that the gray data is recognizable by the production model, we reevaluate the production model with the new gray data. (This step should take ~5 min if you are running on a GPU.)

# %%
x_gray_production, y_gray_production = attack_production.infer(x_init_average, y_gray_production, restore_model_production)
y_gray_production = keras.utils.to_categorical(np.array(y_gray_production), num_classes)

print('\n gray data loss and accuracy based on production model:')
scores_gray_production = restore_model_production.evaluate(x_gray_production, y_gray_production, verbose=1)
print('Gray data loss:', scores_gray_production[0])
print('Gray data accuracy:', scores_gray_production[1])
# Out:
# Model inversion:   0%|          | 0/62 [00:00<?, ?it/s]
# 1/1 [==============================] - 0s 258ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.6851 - accuracy: 0.0000e+00
# Model inversion:   2%|▏         | 1/62 [00:06<06:25,  6.32s/it]
# 1/1 [==============================] - 0s 31ms/step - loss: 8.6044 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 8.4259 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 8.2210 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 7.9704 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 7.6511 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 7.2142 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 6.5770 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 5.4615 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 2.6407 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 2.6226e-05 - accuracy: 1.0000
# Model inversion:   3%|▎         | 2/62 [00:08<03:55,  3.93s/it]
# 1/1 [==============================] - 0s 31ms/step - loss: 12.3239 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.3199 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.3159 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.3119 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.3078 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.3038 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.2996 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.2954 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.2913 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.2870 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.2828 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.2786 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.2743 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.2701 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.2658 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.2615 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.2572 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.2528 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.2485 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.2441 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.2397 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.2354 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.2309 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.2265 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.2221 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.2176 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.2131 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 12.2086 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.2040 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 45ms/step - loss: 12.1995 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.1949 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.1904 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.1859 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.1813 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 12.1768 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 12.1722 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.1676 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.1630 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.1584 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.1537 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 12.1490 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.1443 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.1396 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 45ms/step - loss: 12.1349 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.1301 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.1253 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.1205 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.1157 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1108 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.1060 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.1011 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.0962 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.0912 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.0863 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.0813 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.0763 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.0713 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.0662 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.0611 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.0560 - accuracy: 0.0000e+00
# Model inversion:   5%|▍         | 3/62 [00:15<05:01,  5.11s/it]
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 27.2582 - accuracy: 0.0000e+00
# Model inversion:   6%|▋         | 4/62 [00:20<05:10,  5.35s/it]
# 1/1 [==============================] - 0s 33ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 45ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 50ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 37.6255 - accuracy: 0.0000e+00
# Model inversion:   8%|▊         | 5/62 [00:27<05:32,  5.84s/it]
# 1/1 [==============================] - 0s 30ms/step - loss: 12.7059 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.7030 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.7002 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.6973 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.6944 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.6915 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6887 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.6858 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.6829 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6799 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.6770 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.6741 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.6712 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.6682 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.6653 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.6623 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.6593 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.6564 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6534 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.6504 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.6474 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6444 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6413 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.6383 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.6353 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.6322 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.6292 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.6261 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 12.6231 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.6200 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6169 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.6138 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6107 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6076 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.6044 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.6012 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.5981 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.5949 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.5917 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.5885 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.5852 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.5820 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.5788 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.5755 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.5723 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.5690 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.5657 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.5624 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.5591 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.5558 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.5525 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.5493 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.5461 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 12.5429 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.5397 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.5364 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 12.5332 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.5299 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.5267 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.5234 - accuracy: 0.0000e+00
# Model inversion:  10%|▉         | 6/62 [00:34<05:41,  6.09s/it]
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 57ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 46ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 45ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 45ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 49ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 46ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 52ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 48ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 47ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 48ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 48ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 47ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 18.6587 - accuracy: 0.0000e+00
# Model inversion:  11%|█▏        | 7/62 [00:41<05:58,  6.51s/it]
# 1/1 [==============================] - 0s 35ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 21.5843 - accuracy: 0.0000e+00
# Model inversion:  13%|█▎        | 8/62 [00:47<05:46,  6.41s/it]
# 1/1 [==============================] - 0s 29ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 55ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 42ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 45ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 28.4824 - accuracy: 0.0000e+00
# Model inversion:  15%|█▍        | 9/62 [00:54<05:43,  6.48s/it]
# 1/1 [==============================] - 0s 28ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 18.7417 - accuracy: 0.0000e+00
# ...
# 1/1 [==============================] - 0s 29ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 53ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 42ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 42ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 49ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 43ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 46ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 42ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 46ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 26.8976 - accuracy: 0.0000e+00
# Model inversion:  97%|█████████▋| 60/62 [06:08<00:12,  6.47s/it]
# 1/1 [==============================] - 0s 31ms/step - loss: 14.1159 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.1154 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.1149 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 37ms/step - loss: 14.1144 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 14.1139 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.1134 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 14.1129 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.1124 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.1119 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.1114 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.1109 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.1104 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.1099 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.1094 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 14.1089 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.1084 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.1079 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.1073 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.1068 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 14.1063 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 14.1058 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 14.1053 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 14.1048 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.1043 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.1038 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.1033 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 14.1028 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.1023 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.1018 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.1013 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.1008 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.1003 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 14.0997 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 14.0992 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 14.0987 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.0982 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 14.0977 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 14.0972 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.0967 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 14.0962 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 14.0957 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 14.0952 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 14.0946 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.0941 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 14.0936 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.0931 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.0926 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 24ms/step - loss: 14.0921 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.0916 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 14.0911 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.0905 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 14.0900 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 14.0895 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 33ms/step - loss: 14.0890 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.0885 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 14.0880 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 14.0875 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 14.0869 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 14.0864 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 14.0859 - accuracy: 0.0000e+00
# Model inversion:  98%|█████████▊| 61/62 [06:14<00:06,  6.35s/it]
# 1/1 [==============================] - 0s 28ms/step - loss: 12.8826 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.8810 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8793 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.8776 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.8759 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8742 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8725 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8708 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.8691 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.8674 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.8657 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8640 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.8623 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8606 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8589 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.8571 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8554 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.8537 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.8519 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8502 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8485 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 30ms/step - loss: 12.8468 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.8451 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.8433 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8416 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.8399 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.8381 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 39ms/step - loss: 12.8364 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 12.8346 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 12.8329 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 44ms/step - loss: 12.8312 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 52ms/step - loss: 12.8294 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.8277 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.8259 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 12.8242 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8224 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8207 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 34ms/step - loss: 12.8189 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 59ms/step - loss: 12.8171 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8154 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.8136 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 41ms/step - loss: 12.8118 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 36ms/step - loss: 12.8100 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 42ms/step - loss: 12.8082 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 38ms/step - loss: 12.8065 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 40ms/step - loss: 12.8047 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 35ms/step - loss: 12.8029 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.8011 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.7993 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.7975 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 29ms/step - loss: 12.7957 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 25ms/step - loss: 12.7939 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.7921 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 27ms/step - loss: 12.7903 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 32ms/step - loss: 12.7885 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.7867 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 26ms/step - loss: 12.7849 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 28ms/step - loss: 12.7831 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.7813 - accuracy: 0.0000e+00
# 1/1 [==============================] - 0s 31ms/step - loss: 12.7794 - accuracy: 0.0000e+00
# Model inversion: 100%|██████████| 62/62 [06:21<00:00,  6.15s/it]
#  gray data loss and accuracy based on production model:
# 7/7 [==============================] - 0s 16ms/step - loss: 4.2629e-05 - accuracy: 1.0000
# Gray data loss: 4.2629257222870365e-05
# Gray data accuracy: 1.0

# %% [markdown]
# ## Membership Inference Attacks

# %% [markdown]
# Now that we have our gray data from both the base model and production model, we will use this data to check whether the base model has experienced model drift from the base to the production data.
#
#
# We take both the rule-based membership inference (MI) attack and the black-box MI attack from the [Adversarial Robustness Toolbox example](https://github.com/Trusted-AI/adversarial-robustness-toolbox/blob/main/notebooks/attack_membership_inference_shadow_models.ipynb).

# %%
from art.attacks.inference.membership_inference import MembershipInferenceBlackBox, MembershipInferenceBlackBoxRuleBased
from art.utils import to_categorical
from art.estimators.classification import TensorFlowV2Classifier

restore_model_base2 = tf.keras.models.load_model('model_base.h5')

art_classifier = TensorFlowV2Classifier(restore_model_base2, nb_classes=num_classes, input_shape=(image_size, image_size, image_channels))

# %% [markdown]
# ###Rule-Based Membership Inference Attack

# %%
rb_attack = MembershipInferenceBlackBoxRuleBased(art_classifier)
inferred_test = rb_attack.infer(x_test, y_test)
rb_test_acc = 1 - (np.sum(inferred_test) / len(inferred_test))
print(f"Test Data Accuracy {rb_test_acc:.4f}")
# Out:
# Test Data Accuracy 0.1763

# %% [markdown]
# Here we infer membership of the gray data created from the base model, which should provide a high member accuracy.

# %%
inferred_train = rb_attack.infer(x_gray_base, y_gray_base)

rb_base_train_acc = np.sum(inferred_train) / len(inferred_train)
rb_base_acc = (rb_base_train_acc * len(inferred_train) + rb_test_acc * len(inferred_test)) / (len(inferred_train) + len(inferred_test))
print(f"Base Gray Data Accuracy: {rb_base_train_acc:.4f}")
print(f"Base Attack Accuracy {rb_base_acc:.4f}")
# Out:
# Base Gray Data Accuracy: 1.0000
# Base Attack Accuracy 0.1794

# %% [markdown]
# Now we infer membership of the gray data created from the production model; this accuracy should be lower that the previous if model drift occured.

# %%
prod_inferred_train = rb_attack.infer(x_gray_production, y_gray_production)

rb_prod_train_acc = np.sum(prod_inferred_train) / len(prod_inferred_train)
rb_prod_acc = (rb_prod_train_acc * len(prod_inferred_train) + rb_test_acc * len(inferred_test)) / (len(prod_inferred_train) + len(inferred_test))
print(f"Production Gray Data Accuracy: {rb_prod_train_acc:.4f}")
print(f"Production Attack Accuracy {rb_prod_acc:.4f}")
# Out:
# Production Gray Data Accuracy: 0.7222
# Production Attack Accuracy 0.1773

# %%
print("Rule-Base Model Drift Detection Result:")
result_a = (rb_prod_acc < rb_base_acc)
if result_a:
  rb_score = rb_base_acc - rb_prod_acc
  print(f"drift: {rb_score:.4f}")
else:
  print("no drift detected")

print("Rule-Base Concept Drift Detection Result:")
result_b = (rb_prod_train_acc < rb_base_train_acc)
if result_b:
  rb_score_c = rb_base_train_acc - rb_prod_train_acc
  print(f"drift: {rb_score_c:.4f}")
else:
  print("no drift detected")
# Out:
# Rule-Base Model Drift Detection Result:
# drift: 0.0021
# Rule-Base Concept Drift Detection Result:
# drift: 0.2778

# %% [markdown]
# ###Black-Box Membership Inference Attack

# %% [markdown]
# We run the black-box membership inference attack in the same way as the rule-based attack after fitting the attack model to the base training data that was used to fit the base model originally.

# %%
bb_attack_bb = MembershipInferenceBlackBox(art_classifier)
bb_attack_bb.fit(x_base, y_base, x_test, y_test)

nonmember_infer = bb_attack_bb.infer(x_test, y_test)
bb_nonmember_acc = 1 - np.sum(nonmember_infer) / len(x_test)
print('Test Data Accuracy:', bb_nonmember_acc)
# Out:
# Test Data Accuracy: 0.28442354478478027

# %%
base_member_infer = bb_attack_bb.infer(x_gray_base, y_gray_base)
bb_base_member_acc = np.sum(base_member_infer) / len(x_gray_base)
bb_base_acc = (bb_base_member_acc * len(x_gray_base) + bb_nonmember_acc * len(x_test)) / (len(x_gray_base) + len(x_test))
print('Base Gray Data Accuracy:', bb_base_member_acc)
print('Base Attack Accuracy:', bb_base_acc)
# Out:
# Base Gray Data Accuracy: 1.0
# Base Attack Accuracy: 0.28710785279331275

# %%
production_member_infer = bb_attack_bb.infer(x_gray_production, y_gray_production)
bb_production_member_acc = np.sum(production_member_infer) / len(x_gray_production)
bb_production_acc = (bb_production_member_acc * len(x_gray_production) + bb_nonmember_acc * len(x_test)) / (len(x_gray_production) + len(x_test))
print('Production Gray Data Accuracy:', bb_production_member_acc)
print('Production Attack Accuracy:', bb_production_acc)
# Out:
# Production Gray Data Accuracy: 0.5138888888888888
# Production Attack Accuracy: 0.28484884888320644

# %%
print("Black Box Model Drift Detection Result:")
result_c = (bb_production_acc < bb_base_acc)
if result_c:
  bb_score = bb_base_acc - bb_production_acc
  print(f"drift: {bb_score:.4f}")
else:
  print("no drift detected")

print("Black Box Concept Drift Detection Result:")
result_d = (bb_production_member_acc < bb_base_member_acc)
if result_d:
  bb_score_c = bb_base_member_acc - bb_production_member_acc
  print(f"drift: {bb_score_c:.4f}")
else:
  print("no drift detected")
# Out:
# Black Box Model Drift Detection Result:
# drift: 0.0023
# Black Box Concept Drift Detection Result:
# drift: 0.4861

# %% [markdown]
# ## Model Drift Detection
#
# Let's take a look at the accuracy scores of the membership inference attack with the base gray data compared to the attack with the production gray data.

# %% [markdown]
# ### Concept Drift Detection
# If **production_member_acc** << **base_member_acc** for either attack, then we know that concept drift has occured.

# %%
print("Concept Drift Detection Result:")
print((result_b | result_d))
# Out:
# Concept Drift Detection Result:
# True

# %% [markdown]
# ### Model Drift Detection
# If **bb_production_acc** << **bb_base_acc** for either attack, then we believe that data drift has occured.

# %%
print("Model Drift Detection Result:")
print((result_a | result_c))
# Out:
# Model Drift Detection Result:
# True

# %% [markdown]
# # Configuration Notes

# %% [markdown]
# ## Dataset Configuration
#
# * **data_set**: name of data set mapped to utils.get_data
#
# * **num_classes**: number of classes in dataset
#
# * **image_size**: size of images in dataset
#
# * **image_channels**: number of image channels in dataset
#
# * **data_path**: path to saved data *(default "data")*
#
# * **data_augmentation**: set to *True* if data augmentation should be used to train the model
#
# ## Model Configuration
#
# * **conv_filters**: array for conv filters  *(ex. [4, 8])*
#
# * **dense_units**: size of dense units
#
# * **mode**: training mode *("natural", "robust", or "mini-robust")*
#
# * **depth**:
#
# ## Training Configuration
#
# * **epochs**: number of epochs
#
# * **batch_size**:
#
# * **train_size**:
